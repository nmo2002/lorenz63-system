# %% [markdown]
# **LSTM ARCH (WORKING)**

# %%
# Equation Params
sigma = 10
rho = 28
beta = 8/3
initial_conditions = [-5.0, -10.0, 20.0] # initial conditions

# Time Params
t_end = 100                  # t final
t_points = 1000             # points
lyapunov_exponent = 1       # set to 1 to ignore lyapunov

# Split Param
split_ratio = 1/8

# Scaler Params (don't modify unless you know what you are doing)
feature_range = (0, 1)

# Model Hyperparams (don't need to modify unless want to)
lstm_dim = 512
keep_rate = 0.99
learning_rate = 0.001
epochs = 100
batch_size = 1000

# Params for the iterative forecast 
num_iterations = 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler

# define the Lorenz-63 system


def lorenz63(state, t, sigma, rho, beta):
    x, y, z = state
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    return [dxdt, dydt, dzdt]

# define time span
t = np.linspace(0, t_end, t_points)

# compute Lyapunov time
lyapunov_time = 1 / np.abs(lyapunov_exponent)
t_lyapunov = t / lyapunov_time

# solve Lorenz-63 equations using odeint
solution = odeint(lorenz63, initial_conditions, t_lyapunov, args=(sigma, rho, beta))

# split solutions into separate variables
solution_x = solution[:, 0].reshape(-1, 1)
solution_y = solution[:, 1].reshape(-1, 1)
solution_z = solution[:, 2].reshape(-1, 1)

# split data into input and ground truth
points_length = int(len(solution) * split_ratio)
input_solution_x = solution_x[:points_length]
ground_truth_solution_x = solution_x[points_length:]
input_solution_y = solution_y[:points_length]
ground_truth_solution_y = solution_y[points_length:]
input_solution_z = solution_z[:points_length]
ground_truth_solution_z = solution_z[points_length:]

# scale for each variable
scaler_x = MinMaxScaler(feature_range=feature_range)
scaler_y = MinMaxScaler(feature_range=feature_range)
scaler_z = MinMaxScaler(feature_range=feature_range)

X_train_normalized_x = scaler_x.fit_transform(input_solution_x)
y_train_normalized_x = scaler_x.transform(ground_truth_solution_x)
X_train_normalized_x = np.reshape(X_train_normalized_x, (-1, 1, 1))
y_train_normalized_x = np.reshape(y_train_normalized_x, (-1, 1, 1))

X_train_normalized_y = scaler_y.fit_transform(input_solution_y)
y_train_normalized_y = scaler_y.transform(ground_truth_solution_y)
X_train_normalized_y = np.reshape(X_train_normalized_y, (-1, 1, 1))
y_train_normalized_y = np.reshape(y_train_normalized_y, (-1, 1, 1))

X_train_normalized_z = scaler_z.fit_transform(input_solution_z)
y_train_normalized_z = scaler_z.transform(ground_truth_solution_z)
X_train_normalized_z = np.reshape(X_train_normalized_z, (-1, 1, 1))
y_train_normalized_z = np.reshape(y_train_normalized_z, (-1, 1, 1))

# define LSTM models for each variable

model_x = Sequential([
    LSTM(lstm_dim, input_shape=(X_train_normalized_x.shape[1], 1), return_sequences=True),
    Dropout(1 - keep_rate),
    LSTM(lstm_dim, return_sequences=True),
    Dropout(1 - keep_rate),
    LSTM(lstm_dim),
    Dropout(1 - keep_rate),
    Dense(1)
])

model_y = Sequential([
    LSTM(lstm_dim, input_shape=(X_train_normalized_y.shape[1], 1), return_sequences=True),
    Dropout(1 - keep_rate),
    LSTM(lstm_dim, return_sequences=True),
    Dropout(1 - keep_rate),
    LSTM(lstm_dim),
    Dropout(1 - keep_rate),
    Dense(1)
])

model_z = Sequential([
    LSTM(lstm_dim, input_shape=(X_train_normalized_z.shape[1], 1), return_sequences=True),
    Dropout(1 - keep_rate),
    LSTM(lstm_dim, return_sequences=True),
    Dropout(1 - keep_rate),
    LSTM(lstm_dim),
    Dropout(1 - keep_rate),
    Dense(1)
])

# compile the models
optimizer_x, optimizer_y, optimizer_z = Adam(learning_rate=learning_rate), Adam(learning_rate=learning_rate), Adam(learning_rate=learning_rate)
model_x.compile(optimizer=optimizer_x, loss='mse')
model_y.compile(optimizer=optimizer_y, loss='mse')
model_z.compile(optimizer=optimizer_z, loss='mse')

# train the models
model_x.fit(X_train_normalized_x, X_train_normalized_x, epochs=epochs, batch_size=batch_size, verbose=1)
model_y.fit(X_train_normalized_y, X_train_normalized_y, epochs=epochs, batch_size=batch_size, verbose=1)
model_z.fit(X_train_normalized_z, X_train_normalized_z, epochs=epochs, batch_size=batch_size, verbose=1)

# predict using the trained models
predicted_solution_normalized_x = model_x.predict(y_train_normalized_x)
predicted_solution_normalized_y = model_y.predict(y_train_normalized_y)
predicted_solution_normalized_z = model_z.predict(y_train_normalized_z)

# back to original scale
predicted_solution_x = scaler_x.inverse_transform(predicted_solution_normalized_x).flatten()
predicted_solution_y = scaler_y.inverse_transform(predicted_solution_normalized_y).flatten()
predicted_solution_z = scaler_z.inverse_transform(predicted_solution_normalized_z).flatten()

# Calculate error
# error = np.mean(np.abs(ground_truth_solution_x - predicted_solution_x))
# print("Error:", error)
# Out:
# c:\Users\farxa\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.2140
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.2046
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.1940
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.1809
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.1647
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.1453
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.1226
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0973
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0707
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0456
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0266
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0207
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0326
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0493
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0539
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0465
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.0345
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0247
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0195
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0185
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0203
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0228
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0252
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0264
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0264
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 0.0252
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0231
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0199
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0170
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0141
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0122
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0113
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0114
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0118
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0122
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0117
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0103
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0084
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - loss: 0.0065
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0051
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0044
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0041
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0042
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0040
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0036
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0030
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0021
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0013
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 6.8262e-04
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 3.5719e-04
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 4.1476e-04
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 6.4921e-04
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 7.1386e-04
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 7.1704e-04
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 4.9555e-04
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 2.9117e-04
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 2.2828e-04
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 3.2339e-04
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 5.5120e-04
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 7.1029e-04
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 8.3567e-04
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 7.2741e-04
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 5.8920e-04
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 4.8968e-04
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 4.1586e-04
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 4.5693e-04
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 4.5623e-04
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 4.7683e-04
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 3.9178e-04
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 2.6352e-04
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 1.4119e-04
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.0987e-04
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 1.0162e-04
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.2861e-04
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.2385e-04
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1.1848e-04
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 9.2214e-05
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 5.1795e-05
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 3.8551e-05
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 7.2792e-05
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 8.5636e-05
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 1.0756e-04
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.1295e-04
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 9.8826e-05
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 8.3693e-05
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 7.7968e-05
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 8.7842e-05
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 9.0185e-05
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 9.3921e-05
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 8.1009e-05
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 6.2442e-05
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 6.0410e-05
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 6.2343e-05
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 5.6642e-05
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 5.4776e-05
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 5.7509e-05
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 3.7145e-05
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 3.6428e-05
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 4.1439e-05
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 3.9503e-05
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.2238
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2137
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2023
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.1884
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.1713
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.1506
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.1265
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0995
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0710
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0442
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0240
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0178
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0312
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0489
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0539
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0458
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0331
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0228
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0175
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0166
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0186
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0215
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0239
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0257
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0259
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0247
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0223
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0197
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0165
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0137
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0118
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0109
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0113
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0120
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0126
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0123
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0111
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - loss: 0.0093
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0075
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0062
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0053
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.0050
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0050
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0050
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0047
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0041
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0033
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0023
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0015
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0010
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 8.6504e-04
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 9.0150e-04
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 9.8900e-04
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 8.4684e-04
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 6.6154e-04
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 3.1202e-04
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 7.9397e-05
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 6.2456e-05
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 2.0374e-04
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 3.9068e-04
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 5.1980e-04
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 5.6135e-04
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 4.6505e-04
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 3.8645e-04
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 3.0791e-04
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 3.9656e-04
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 4.4539e-04
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 5.1545e-04
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 5.1442e-04
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 4.1146e-04
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 2.6385e-04
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 2.0568e-04
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 2.1118e-04
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 2.0096e-04
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 2.1005e-04
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.9459e-04
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 1.2596e-04
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 8.3541e-05
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 5.7394e-05
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 4.7731e-05
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 6.8153e-05
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 7.0221e-05
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 8.8048e-05
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 5.5036e-05
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 5.1448e-05
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 4.8954e-05
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 5.7937e-05
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 7.0300e-05
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 7.5618e-05
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 7.6427e-05
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 7.7260e-05
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 6.7695e-05
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 5.3386e-05
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 6.2808e-05
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 6.0007e-05
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 7.1528e-05
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 6.6476e-05
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 5.4580e-05
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 4.2395e-05
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 4.6818e-05
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 0.2915
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.2796
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.2662
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2497
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.2289
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.2036
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.1736
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.1397
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.1030
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - loss: 0.0670
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0377
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0235
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0338
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0591
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0714
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0637
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0477
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0327
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0238
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0211
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0230
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0267
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0300
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0322
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0328
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0316
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0291
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0251
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0211
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0173
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0143
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0127
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0127
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0136
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0144
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0143
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0129
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.0107
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0083
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0063
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0052
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0047
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0048
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0048
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0047
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0041
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 0.0032
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0023
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0012
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 6.5470e-04
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 4.7637e-04
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 6.5532e-04
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 8.7349e-04
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0010
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 8.8737e-04
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 4.9420e-04
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 2.1301e-04
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 1.5884e-04
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 2.4711e-04
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 4.8604e-04
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 7.1481e-04
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 7.9425e-04
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 7.5979e-04
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 6.1462e-04
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 4.7241e-04
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 4.0446e-04
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - loss: 4.5781e-04
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 5.1996e-04
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 5.4392e-04
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 4.6171e-04
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 3.8519e-04
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 2.7696e-04
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.7537e-04
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.3867e-04
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 1.6247e-04
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.8597e-04
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.6756e-04
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.2744e-04
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 9.4281e-05
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 4.7604e-05
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 5.0135e-05
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 6.3220e-05
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - loss: 6.8526e-05
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 9.3338e-05
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 9.2901e-05
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 8.7310e-05
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 6.7391e-05
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 7.3860e-05
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 7.6041e-05
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 9.0552e-05
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 8.7767e-05
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 8.4175e-05
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 8.2344e-05
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 6.9614e-05
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 6.4565e-05
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 6.5388e-05
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 6.3214e-05
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 6.8261e-05
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 5.8918e-05
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 5.2113e-05
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %%
def iterative_forecast(model, initial_input, scaler, num_iterations, split_num, epochs):
    all_predictions = initial_input.copy()  # Make a copy of initial input
    for i in range(num_iterations):
        # define time span
        split_num = int(1/split_num)
        t = np.linspace(0, t_end*split_num**(i+1), t_points*split_num**(i+1))
        t = t / lyapunov_time

        # lorenz solved
        solution = odeint(lorenz63, initial_conditions, t, args=(sigma, rho, beta))
        solution = solution[:, 0].reshape(-1, 1)
        points_length = int(len(solution) * split_ratio)
        input_solution = all_predictions
        ground_truth_solution = solution[points_length:]

        # normalize input data
        input_data_scaled = scaler.fit_transform(input_solution.reshape(-1, 1))
        ground_truth_solution_scaled = scaler.transform(ground_truth_solution.reshape(-1, 1))
        input_data_scaled = np.reshape(input_data_scaled, (-1, 1, 1))
        ground_truth_solution_scaled = np.reshape(ground_truth_solution_scaled, (-1, 1, 1))
    
        # train
        model.fit(input_data_scaled, input_data_scaled, epochs=epochs, batch_size=t_points, verbose=1)

        # predict
        predicted_solution_normalized = model.predict(ground_truth_solution_scaled)

        # back to original
        predicted_solution = scaler.inverse_transform(predicted_solution_normalized).flatten()

        # append
        all_predictions = np.concatenate((all_predictions, predicted_solution.reshape(-1, 1)))

        plt.figure(figsize=(9, 3))
        plt.plot(t[:points_length], input_solution, label='Input', color='black')
        plt.plot(t[points_length:], ground_truth_solution, label='Ground Truth', color='orange')
        plt.scatter(t[points_length:], predicted_solution, label='Prediction', color='blue', linestyle='--', s=10)
        plt.xlabel('Lyapunov Time')
        plt.ylabel('X')
        plt.legend()

# perform recursive prediction for x variable
all_predictions_x = iterative_forecast(model_x, np.concatenate((input_solution_x, predicted_solution_x.reshape(-1, 1))), scaler_x, num_iterations, split_ratio, epochs)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step - loss: 4.0548e-05
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - loss: 4.3517e-05
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - loss: 4.2393e-05
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 4.1227e-05
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - loss: 4.1323e-05
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - loss: 3.7044e-05
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - loss: 3.5603e-05
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 3.8909e-05
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 3.5539e-05
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 3.5635e-05
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 3.4487e-05
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 3.3271e-05
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 3.9404e-05
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 3.5294e-05
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 3.5013e-05
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 3.5771e-05
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 3.3804e-05
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - loss: 3.3972e-05
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 3.4086e-05
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 3.3051e-05
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 3.5079e-05
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 3.4247e-05
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 3.4455e-05
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 3.5773e-05
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 3.3502e-05
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - loss: 3.4142e-05
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 3.4149e-05
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 3.5131e-05
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 3.2664e-05
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 3.3486e-05
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - loss: 3.3397e-05
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 3.6587e-05
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 3.3408e-05
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 3.1650e-05
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 3.3258e-05
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 3.1464e-05
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 3.1872e-05
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 3.2685e-05
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 3.1078e-05
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 3.2669e-05
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - loss: 3.1711e-05
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - loss: 3.0365e-05
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - loss: 3.1616e-05
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 3.3684e-05
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 3.0995e-05
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - loss: 2.8749e-05
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 3.0210e-05
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 3.3151e-05
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 3.3185e-05
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 2.9344e-05
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 3.3543e-05
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 2.9714e-05
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - loss: 3.0131e-05
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 3.1163e-05
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 3.0221e-05
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 3.2071e-05
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 2.9049e-05
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 2.8678e-05
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 3.1742e-05
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - loss: 3.1345e-05
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - loss: 3.0053e-05
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 3.0792e-05
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 2.8134e-05
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 3.1858e-05
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 3.0413e-05
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 3.2710e-05
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 2.8589e-05
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 3.0103e-05
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - loss: 2.6622e-05
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - loss: 2.5959e-05
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 2.8406e-05
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 3.0769e-05
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 2.8899e-05
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 2.6347e-05
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - loss: 2.8029e-05
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 2.9367e-05
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - loss: 2.8617e-05
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - loss: 2.6920e-05
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 2.7038e-05
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 3.0085e-05
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 2.8642e-05
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 2.8815e-05
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 2.7021e-05
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - loss: 2.8481e-05
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 2.6971e-05
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - loss: 2.7890e-05
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - loss: 2.6805e-05
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 2.8237e-05
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 2.6735e-05
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 2.8761e-05
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - loss: 2.7306e-05
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 2.8036e-05
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 2.6223e-05
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 2.4776e-05
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 2.7983e-05
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - loss: 2.7049e-05
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - loss: 2.8058e-05
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 2.6507e-05
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 2.8183e-05
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - loss: 2.5661e-05
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
# plot
plt.figure(figsize=(10, 18))

plt.subplot(3, 1, 1)
plt.plot(t_lyapunov[:points_length], input_solution_x, label='Input', color='black')
plt.plot(t_lyapunov[points_length:], ground_truth_solution_x, label='Ground Truth', color='orange')
plt.scatter(t_lyapunov[points_length:], predicted_solution_x, label='Prediction', color='blue', linestyle='--', s=10)
plt.xlabel('Lyapunov Time')
plt.ylabel('X')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(t_lyapunov[:points_length], input_solution_y, label='Input', color='black')
plt.plot(t_lyapunov[points_length:], ground_truth_solution_y, label='Ground Truth', color='orange')
plt.scatter(t_lyapunov[points_length:], predicted_solution_y, label='Prediction', color='blue', linestyle='--', s=10)
plt.xlabel('Lyapunov Time')
plt.ylabel('Y')
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(t_lyapunov[:points_length], input_solution_z, label='Input', color='black')
plt.plot(t_lyapunov[points_length:], ground_truth_solution_z, label='Ground Truth', color='orange')
plt.scatter(t_lyapunov[points_length:], predicted_solution_z, label='Prediction', color='blue', linestyle='--', s=10)
plt.xlabel('Lyapunov Time')
plt.ylabel('Z')
plt.legend()

plt.suptitle('Lorenz-63 System Prediction with LSTM (Separate Training for Each Variable)')
plt.tight_layout()

# 3d model
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# ground truth trajectory
ax.plot(solution_x.flatten(), solution_y.flatten(), solution_z.flatten(), label='Ground Truth', color='orange')

# prediction
ax.scatter(predicted_solution_x, predicted_solution_y, predicted_solution_z, label='Prediction', color='blue')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Lorenz-63 System Trajectory')

plt.legend()
plt.show()
