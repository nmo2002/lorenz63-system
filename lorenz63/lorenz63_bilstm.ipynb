# %% [markdown]
# **BI-LSTM ARCH (WORKING)**

# %%
# Equation Params
sigma = 10
rho = 28
beta = 8/3
initial_conditions = [-5.0, -10.0, 20.0] # initial conditions

# Time Params
t_end = 100                  # t final
t_points = 1000             # points
lyapunov_exponent = 1       # set to 1 to ignore lyapunov

# Split Param
split_ratio = 1/8

# Scaler Params (don't modify unless you know what you are doing)
feature_range = (0, 1)

# Model Hyperparams (don't need to modify unless want to)
lstm_dim = 512
keep_rate = 0.99
learning_rate = 0.001
epochs = 100
batch_size = 1000

# Params for the iterative forecast 
num_iterations = 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional
from keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler

# define the Lorenz-63 system


def lorenz63(state, t, sigma, rho, beta):
    x, y, z = state
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    return [dxdt, dydt, dzdt]

# define time span
t = np.linspace(0, t_end, t_points)

# compute Lyapunov time
lyapunov_time = 1 / np.abs(lyapunov_exponent)
t_lyapunov = t / lyapunov_time

# solve Lorenz-63 equations using odeint
solution = odeint(lorenz63, initial_conditions, t_lyapunov, args=(sigma, rho, beta))

# split solutions into separate variables
solution_x = solution[:, 0].reshape(-1, 1)
solution_y = solution[:, 1].reshape(-1, 1)
solution_z = solution[:, 2].reshape(-1, 1)

# split data into input and ground truth
points_length = int(len(solution) * split_ratio)
input_solution_x = solution_x[:points_length]
ground_truth_solution_x = solution_x[points_length:]
input_solution_y = solution_y[:points_length]
ground_truth_solution_y = solution_y[points_length:]
input_solution_z = solution_z[:points_length]
ground_truth_solution_z = solution_z[points_length:]

# scale for each variable

scaler_x = MinMaxScaler(feature_range=feature_range)
scaler_y = MinMaxScaler(feature_range=feature_range)
scaler_z = MinMaxScaler(feature_range=feature_range)

X_train_normalized_x = scaler_x.fit_transform(input_solution_x)
y_train_normalized_x = scaler_x.transform(ground_truth_solution_x)
X_train_normalized_x = np.reshape(X_train_normalized_x, (-1, 1, 1))
y_train_normalized_x = np.reshape(y_train_normalized_x, (-1, 1, 1))

X_train_normalized_y = scaler_y.fit_transform(input_solution_y)
y_train_normalized_y = scaler_y.transform(ground_truth_solution_y)
X_train_normalized_y = np.reshape(X_train_normalized_y, (-1, 1, 1))
y_train_normalized_y = np.reshape(y_train_normalized_y, (-1, 1, 1))

X_train_normalized_z = scaler_z.fit_transform(input_solution_z)
y_train_normalized_z = scaler_z.transform(ground_truth_solution_z)
X_train_normalized_z = np.reshape(X_train_normalized_z, (-1, 1, 1))
y_train_normalized_z = np.reshape(y_train_normalized_z, (-1, 1, 1))

# define LSTM models for each variable

model_x = Sequential([
    LSTM(lstm_dim, input_shape=(X_train_normalized_x.shape[1], 1), return_sequences=True),
    Dropout(1 - keep_rate),
    Bidirectional(LSTM(lstm_dim, return_sequences=True)),
    Dropout(1 - keep_rate),
    Bidirectional(LSTM(lstm_dim)),
    Dropout(1 - keep_rate),
    Dense(1)
])

model_y = Sequential([
    LSTM(lstm_dim, input_shape=(X_train_normalized_y.shape[1], 1), return_sequences=True),
    Dropout(1 - keep_rate),
    Bidirectional(LSTM(lstm_dim, return_sequences=True)),
    Dropout(1 - keep_rate),
    Bidirectional(LSTM(lstm_dim)),
    Dropout(1 - keep_rate),
    Dense(1)
])

model_z = Sequential([
    LSTM(lstm_dim, input_shape=(X_train_normalized_z.shape[1], 1), return_sequences=True),
    Dropout(1 - keep_rate),
    Bidirectional(LSTM(lstm_dim, return_sequences=True)),
    Dropout(1 - keep_rate),
    Bidirectional(LSTM(lstm_dim)),
    Dropout(1 - keep_rate),
    Dense(1)
])

# compile the models
optimizer_x, optimizer_y, optimizer_z = Adam(learning_rate=learning_rate), Adam(learning_rate=learning_rate), Adam(learning_rate=learning_rate)
model_x.compile(optimizer=optimizer_x, loss='mse')
model_y.compile(optimizer=optimizer_y, loss='mse')
model_z.compile(optimizer=optimizer_z, loss='mse')

# train the models
model_x.fit(X_train_normalized_x, X_train_normalized_x, epochs=epochs, batch_size=batch_size, verbose=1)
model_y.fit(X_train_normalized_y, X_train_normalized_y, epochs=epochs, batch_size=batch_size, verbose=1)
model_z.fit(X_train_normalized_z, X_train_normalized_z, epochs=epochs, batch_size=batch_size, verbose=1)

# predict using the trained models
predicted_solution_normalized_x = model_x.predict(y_train_normalized_x)
predicted_solution_normalized_y = model_y.predict(y_train_normalized_y)
predicted_solution_normalized_z = model_z.predict(y_train_normalized_z)

# back to original scale
predicted_solution_x = scaler_x.inverse_transform(predicted_solution_normalized_x).flatten()
predicted_solution_y = scaler_y.inverse_transform(predicted_solution_normalized_y).flatten()
predicted_solution_z = scaler_z.inverse_transform(predicted_solution_normalized_z).flatten()

# Calculate error
# error = np.mean(np.abs(ground_truth_solution_x - predicted_solution_x))
# print("Error:", error)
# Out:
# c:\Users\farxa\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - loss: 0.2129
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step - loss: 0.1980
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - loss: 0.1801
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - loss: 0.1562
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - loss: 0.1255
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - loss: 0.0895
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - loss: 0.0525
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - loss: 0.0241
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - loss: 0.0207
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - loss: 0.0469
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - loss: 0.0602
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 0.0495
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - loss: 0.0318
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - loss: 0.0197
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - loss: 0.0162
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - loss: 0.0185
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step - loss: 0.0228
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - loss: 0.0265
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - loss: 0.0283
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - loss: 0.0278
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - loss: 0.0253
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - loss: 0.0214
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - loss: 0.0170
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - loss: 0.0129
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - loss: 0.0103
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - loss: 0.0096
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - loss: 0.0105
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - loss: 0.0119
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - loss: 0.0121
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - loss: 0.0107
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - loss: 0.0080
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - loss: 0.0053
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - loss: 0.0036
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - loss: 0.0031
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step - loss: 0.0034
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 0.0038
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - loss: 0.0038
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - loss: 0.0033
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - loss: 0.0022
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - loss: 0.0011
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - loss: 2.4547e-04
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - loss: 8.4261e-05
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step - loss: 5.0083e-04
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - loss: 0.0011
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 0.0014
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - loss: 0.0012
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - loss: 7.2124e-04
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - loss: 4.6435e-04
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - loss: 5.4877e-04
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - loss: 8.5712e-04
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - loss: 0.0011
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step - loss: 0.0012
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - loss: 9.8086e-04
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - loss: 6.6554e-04
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - loss: 4.2583e-04
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - loss: 3.5138e-04
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step - loss: 4.0516e-04
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - loss: 4.5368e-04
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - loss: 4.1014e-04
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - loss: 2.6011e-04
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - loss: 1.0512e-04
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step - loss: 2.5633e-05
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step - loss: 4.3033e-05
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - loss: 1.1452e-04
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - loss: 1.6333e-04
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - loss: 1.7450e-04
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - loss: 1.2514e-04
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - loss: 7.7086e-05
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - loss: 5.9554e-05
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - loss: 8.9247e-05
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - loss: 1.3057e-04
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - loss: 1.5242e-04
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - loss: 1.4139e-04
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - loss: 1.0697e-04
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - loss: 7.4619e-05
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - loss: 6.5926e-05
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - loss: 6.8826e-05
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - loss: 7.6039e-05
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - loss: 7.3086e-05
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - loss: 5.9170e-05
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 3.2810e-05
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - loss: 2.1057e-05
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - loss: 1.8308e-05
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 2.5256e-05
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step - loss: 3.1725e-05
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - loss: 3.0878e-05
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 2.2088e-05
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step - loss: 1.4450e-05
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - loss: 1.8147e-05
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - loss: 2.4761e-05
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - loss: 3.0785e-05
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - loss: 2.9822e-05
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 2.5083e-05
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step - loss: 2.1031e-05
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - loss: 1.9647e-05
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - loss: 2.0191e-05
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - loss: 2.6097e-05
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - loss: 2.4082e-05
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 1.9437e-05
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - loss: 1.5211e-05
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step - loss: 0.2153
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 766ms/step - loss: 0.2003
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - loss: 0.1819
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step - loss: 0.1572
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step - loss: 0.1257
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 533ms/step - loss: 0.0886
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 675ms/step - loss: 0.0504
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 536ms/step - loss: 0.0209
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - loss: 0.0169
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step - loss: 0.0443
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 0.0584
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - loss: 0.0476
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - loss: 0.0294
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - loss: 0.0171
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - loss: 0.0136
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - loss: 0.0161
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step - loss: 0.0208
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - loss: 0.0248
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - loss: 0.0269
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - loss: 0.0268
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - loss: 0.0248
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - loss: 0.0212
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - loss: 0.0170
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step - loss: 0.0132
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - loss: 0.0106
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - loss: 0.0098
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step - loss: 0.0108
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step - loss: 0.0125
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - loss: 0.0134
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step - loss: 0.0126
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - loss: 0.0104
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - loss: 0.0078
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - loss: 0.0059
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 578ms/step - loss: 0.0051
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - loss: 0.0051
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - loss: 0.0055
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step - loss: 0.0057
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step - loss: 0.0054
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - loss: 0.0045
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step - loss: 0.0033
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 0.0021
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - loss: 0.0013
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - loss: 0.0010
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - loss: 0.0012
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step - loss: 0.0015
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step - loss: 0.0014
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - loss: 9.2595e-04
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step - loss: 3.5478e-04
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - loss: 3.5545e-05
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - loss: 8.3860e-05
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - loss: 3.8288e-04
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - loss: 6.7895e-04
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - loss: 7.7170e-04
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - loss: 6.3810e-04
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step - loss: 4.2219e-04
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 636ms/step - loss: 3.1381e-04
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - loss: 3.9085e-04
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - loss: 5.6590e-04
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - loss: 6.7038e-04
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step - loss: 6.0616e-04
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - loss: 4.2480e-04
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step - loss: 2.7795e-04
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 2.2584e-04
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step - loss: 2.4711e-04
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - loss: 2.8580e-04
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - loss: 2.6088e-04
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - loss: 1.8859e-04
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step - loss: 9.2036e-05
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - loss: 3.3086e-05
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - loss: 3.1171e-05
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - loss: 6.8012e-05
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - loss: 9.1419e-05
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - loss: 8.3804e-05
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - loss: 5.3514e-05
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 2.9120e-05
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - loss: 3.0338e-05
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - loss: 5.0741e-05
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - loss: 7.4839e-05
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - loss: 8.5030e-05
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - loss: 7.0034e-05
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - loss: 5.2562e-05
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - loss: 4.5015e-05
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step - loss: 4.7059e-05
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - loss: 5.4863e-05
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 632ms/step - loss: 5.7114e-05
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step - loss: 5.0398e-05
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - loss: 3.6637e-05
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 547ms/step - loss: 2.6024e-05
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - loss: 2.3260e-05
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - loss: 2.6898e-05
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step - loss: 2.7481e-05
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 542ms/step - loss: 2.3527e-05
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step - loss: 1.7015e-05
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step - loss: 1.2597e-05
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 553ms/step - loss: 1.2292e-05
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step - loss: 1.5707e-05
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 550ms/step - loss: 1.9392e-05
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step - loss: 1.4976e-05
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step - loss: 1.5491e-05
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step - loss: 1.3898e-05
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step - loss: 0.2599
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step - loss: 0.2424
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step - loss: 0.2207
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.1913
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.1537
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.1094
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step - loss: 0.0639
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 819ms/step - loss: 0.0287
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 890ms/step - loss: 0.0233
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step - loss: 0.0550
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 863ms/step - loss: 0.0727
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0603
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step - loss: 0.0386
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step - loss: 0.0233
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 865ms/step - loss: 0.0184
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0209
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step - loss: 0.0263
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 896ms/step - loss: 0.0309
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 867ms/step - loss: 0.0334
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 894ms/step - loss: 0.0331
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 878ms/step - loss: 0.0302
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step - loss: 0.0255
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 876ms/step - loss: 0.0201
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 901ms/step - loss: 0.0151
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 844ms/step - loss: 0.0117
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 879ms/step - loss: 0.0107
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 931ms/step - loss: 0.0118
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 898ms/step - loss: 0.0136
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step - loss: 0.0142
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0127
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 915ms/step - loss: 0.0096
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step - loss: 0.0064
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 992ms/step - loss: 0.0042
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step - loss: 0.0034
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step - loss: 0.0037
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0043
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0046
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0041
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0030
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step - loss: 0.0016
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.7256e-04
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 6.9171e-05
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.2301e-04
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step - loss: 0.0011
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0016
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0015
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 9.9981e-04
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 5.6689e-04
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.7290e-04
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 7.5614e-04
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0011
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0014
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.0013
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 9.3427e-04
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 5.8166e-04
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.9893e-04
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.0858e-04
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 5.1838e-04
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 973ms/step - loss: 5.4688e-04
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4.4448e-04
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 2.4948e-04
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step - loss: 8.5970e-05
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step - loss: 3.0760e-05
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 7.8848e-05
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.6184e-04
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 2.0928e-04
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.7505e-04
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.0955e-04
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 6.0060e-05
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 5.7185e-05
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 9.6589e-05
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.4765e-04
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.6749e-04
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.4700e-04
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step - loss: 1.0446e-04
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step - loss: 7.3260e-05
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step - loss: 6.6809e-05
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 907ms/step - loss: 8.5714e-05
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 9.7761e-05
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 8.7119e-05
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 971ms/step - loss: 5.9333e-05
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 3.7610e-05
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 2.2955e-05
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 2.5985e-05
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 818ms/step - loss: 3.2940e-05
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step - loss: 3.7128e-05
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step - loss: 3.3410e-05
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 858ms/step - loss: 2.1986e-05
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step - loss: 1.6046e-05
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 1.7906e-05
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 804ms/step - loss: 2.3999e-05
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 836ms/step - loss: 2.8984e-05
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 894ms/step - loss: 3.1676e-05
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 814ms/step - loss: 2.7013e-05
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step - loss: 2.1355e-05
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 790ms/step - loss: 1.8872e-05
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step - loss: 2.1478e-05
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 729ms/step - loss: 2.6315e-05
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step - loss: 2.4492e-05
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step - loss: 2.1375e-05
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step

# %%
def iterative_forecast(model, initial_input, scaler, num_iterations, split_num, epochs):
    all_predictions = initial_input.copy()  # Make a copy of initial input
    for i in range(num_iterations):
        # define time span
        split_num = int(1/split_num)
        t = np.linspace(0, t_end*split_num**(i+1), t_points*split_num**(i+1))
        t = t / lyapunov_time

        # lorenz solved
        solution = odeint(lorenz63, initial_conditions, t, args=(sigma, rho, beta))
        solution = solution[:, 0].reshape(-1, 1)
        points_length = int(len(solution) * split_ratio)
        input_solution = all_predictions
        ground_truth_solution = solution[points_length:]

        # normalize input data
        input_data_scaled = scaler.fit_transform(input_solution.reshape(-1, 1))
        ground_truth_solution_scaled = scaler.transform(ground_truth_solution.reshape(-1, 1))
        input_data_scaled = np.reshape(input_data_scaled, (-1, 1, 1))
        ground_truth_solution_scaled = np.reshape(ground_truth_solution_scaled, (-1, 1, 1))
    
        # train
        model.fit(input_data_scaled, input_data_scaled, epochs=epochs, batch_size=t_points, verbose=1)

        # predict
        predicted_solution_normalized = model.predict(ground_truth_solution_scaled)

        # back to original
        predicted_solution = scaler.inverse_transform(predicted_solution_normalized).flatten()

        # append
        all_predictions = np.concatenate((all_predictions, predicted_solution.reshape(-1, 1)))

        plt.figure(figsize=(9, 3))
        plt.plot(t[:points_length], input_solution, label='Input', color='black')
        plt.plot(t[points_length:], ground_truth_solution, label='Ground Truth', color='orange')
        plt.scatter(t[points_length:], predicted_solution, label='Prediction', color='blue', linestyle='--', s=10)
        plt.xlabel('Lyapunov Time')
        plt.ylabel('X')
        plt.legend()

# perform recursive prediction for x variable
all_predictions_x = iterative_forecast(model_x, np.concatenate((input_solution_x, predicted_solution_x.reshape(-1, 1))), scaler_x, num_iterations, split_ratio, epochs)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.2206e-05
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2345e-05
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1885e-05
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2253e-05
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2382e-05
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2401e-05
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1947e-05
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2416e-05
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2354e-05
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1806e-05
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2205e-05
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2022e-05
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2284e-05
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1908e-05
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2478e-05
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2248e-05
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1970e-05
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2175e-05
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2097e-05
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2020e-05
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.2290e-05
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2155e-05
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1746e-05
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2080e-05
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1883e-05
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2263e-05
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2078e-05
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2173e-05
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2060e-05
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1955e-05
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2097e-05
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1654e-05
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1786e-05
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2327e-05
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2035e-05
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2067e-05
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2118e-05
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1818e-05
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1921e-05
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1654e-05
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1792e-05
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1927e-05
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1847e-05
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.2191e-05
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1620e-05
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1789e-05
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2034e-05
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2252e-05
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1969e-05
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1970e-05
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1949e-05
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2432e-05
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1719e-05
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1683e-05
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1614e-05
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2287e-05
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1825e-05
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2055e-05
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1626e-05
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1675e-05
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2192e-05
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1570e-05
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2197e-05
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1986e-05
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1840e-05
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1728e-05
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2009e-05
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1699e-05
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2309e-05
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.2087e-05
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1775e-05
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1790e-05
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1465e-05
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 1.1775e-05
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1894e-05
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1391e-05
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1902e-05
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 1.2496e-05
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1550e-05
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1149e-05
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1586e-05
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1569e-05
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1687e-05
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1713e-05
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1796e-05
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1408e-05
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1746e-05
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1806e-05
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1472e-05
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1642e-05
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1501e-05
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1743e-05
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1543e-05
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1552e-05
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 1.1821e-05
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1802e-05
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1836e-05
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 1.1554e-05
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 1.1203e-05
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - loss: 1.1271e-05
# 2188/2188 ━━━━━━━━━━━━━━━━━━━━ 30s 14ms/step
# C:\Users\farxa\AppData\Roaming\Python\Python311\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\farxa\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# plot
plt.figure(figsize=(10, 18))

plt.subplot(3, 1, 1)
plt.plot(t_lyapunov[:points_length], input_solution_x, label='Input', color='black')
plt.plot(t_lyapunov[points_length:], ground_truth_solution_x, label='Ground Truth', color='orange')
plt.scatter(t_lyapunov[points_length:], predicted_solution_x, label='Prediction', color='blue', linestyle='--', s=10)
plt.xlabel('Lyapunov Time')
plt.ylabel('X')
plt.legend()

plt.subplot(3, 1, 2)
plt.plot(t_lyapunov[:points_length], input_solution_y, label='Input', color='black')
plt.plot(t_lyapunov[points_length:], ground_truth_solution_y, label='Ground Truth', color='orange')
plt.scatter(t_lyapunov[points_length:], predicted_solution_y, label='Prediction', color='blue', linestyle='--', s=10)
plt.xlabel('Lyapunov Time')
plt.ylabel('Y')
plt.legend()

plt.subplot(3, 1, 3)
plt.plot(t_lyapunov[:points_length], input_solution_z, label='Input', color='black')
plt.plot(t_lyapunov[points_length:], ground_truth_solution_z, label='Ground Truth', color='orange')
plt.scatter(t_lyapunov[points_length:], predicted_solution_z, label='Prediction', color='blue', linestyle='--', s=10)
plt.xlabel('Lyapunov Time')
plt.ylabel('Z')
plt.legend()

plt.suptitle('Lorenz-63 System Prediction with BiLSTM (Separate Training for Each Variable)')
plt.tight_layout()

# 3d model
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# ground truth trajectory
ax.plot(solution_x.flatten(), solution_y.flatten(), solution_z.flatten(), label='Ground Truth', color='orange')

# prediction
ax.scatter(predicted_solution_x, predicted_solution_y, predicted_solution_z, label='Prediction', color='blue')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Lorenz-63 System Trajectory')

plt.legend()
plt.show()
